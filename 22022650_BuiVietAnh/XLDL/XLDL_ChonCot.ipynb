# %%
import os
import pandas as pd

# %%
# Lấy đường dẫn của thư mục hiện tại
current_directory = os.getcwd()

# Lấy đường dẫn của thư mục cha
parent_directory = os.path.dirname(current_directory)

# Tạo đường dẫn đầy đủ tới file CSV
csv_path = os.path.join(parent_directory, "CartoonNetworkAsia_81Post_Raw.csv")

# Đọc file CSV
raw_df = pd.read_csv(csv_path)

# %%
raw_df
# Out:
#     Unnamed: 0          post_id  \
# 0            0  738496031649666
# 1            1  738486251650644
# 2            2  736838365148766
# 3            3  737572781741991
# 4            4  736877231811546
# ..         ...              ...
# 76          76  681911200641483
# 77          77  681542050678398
# 78          78  681350087364261
# 79          79  681290900703513
# 80          80  680769534088983
#
#                                                  text  \
# 0   Celebrate #WB100 with sunset movies under the ...
# 1   Unlock your Barbie and Chelsea alter ego! Try ...
# 2   Looks like Tom won't be fishing in the Singapo...
# 3   The chase is on in the Singapore Botanic Garde...
# 4   Ready to rock some outdoor superhero moves? ⚡️...
# ..                                                ...
# 76  The claws are out this August with Cat-stravag...
# 77  Toontastic Kenergy all around 💯 Which of these...
# 78  Celebrate the 9 lives of Cats with Cat-stravag...
# ...

# %%
# lựa chọn các thuộc tính cần phân tích
new_df_01 = raw_df[["post_id", "post_text", "time", "likes", "comments", "shares", "reactions", "reaction_count"]]

# %%
new_df_01
# Out:
#             post_id                                          post_text  \
# 0   738496031649666  Celebrate #WB100 with sunset movies under the ...
# 1   738486251650644  Unlock your Barbie and Chelsea alter ego! Try ...
# 2   736838365148766  Looks like Tom won't be fishing in the Singapo...
# 3   737572781741991  The chase is on in the Singapore Botanic Garde...
# 4   736877231811546  Ready to rock some outdoor superhero moves? ⚡️...
# ..              ...                                                ...
# 76  681911200641483  The claws are out this August with Cat-stravag...
# 77  681542050678398  Toontastic Kenergy all around 💯 Which of these...
# 78  681350087364261  Celebrate the 9 lives of Cats with Cat-stravag...
# 79  681290900703513  The iconic chase continues between Tom and Jer...
# 80  680769534088983  Did someone say FRIENDSHIP QUIZ? 👯‍♀️🧐 Happy I...
#
#                    time  likes  comments  shares  \
# 0   2023-11-06 11:35:32     37         0       0
# ...

# %%
# loại bỏ các dòng có giá trị không phù hợp
new_df_02 = new_df_01.dropna()

# %%
new_df_02
# Out:
#             post_id                                          post_text  \
# 0   738496031649666  Celebrate #WB100 with sunset movies under the ...
# 1   738486251650644  Unlock your Barbie and Chelsea alter ego! Try ...
# 2   736838365148766  Looks like Tom won't be fishing in the Singapo...
# 3   737572781741991  The chase is on in the Singapore Botanic Garde...
# 4   736877231811546  Ready to rock some outdoor superhero moves? ⚡️...
# ..              ...                                                ...
# 76  681911200641483  The claws are out this August with Cat-stravag...
# 77  681542050678398  Toontastic Kenergy all around 💯 Which of these...
# 78  681350087364261  Celebrate the 9 lives of Cats with Cat-stravag...
# 79  681290900703513  The iconic chase continues between Tom and Jer...
# 80  680769534088983  Did someone say FRIENDSHIP QUIZ? 👯‍♀️🧐 Happy I...
#
#                    time  likes  comments  shares  \
# 0   2023-11-06 11:35:32     37         0       0
# ...

# %%
# lưu dataframe dưới tên CartoonNetworkAsia_81Post_Processing_01.csv
new_df_02.to_csv("CartoonNetworkAsia_81Post_Processing_01.csv", index = False)
