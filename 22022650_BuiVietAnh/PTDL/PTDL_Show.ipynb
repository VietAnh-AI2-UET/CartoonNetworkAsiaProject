# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Lấy đường dẫn của thư mục hiện tại
current_directory = os.getcwd()

# Lấy đường dẫn của thư mục cha
parent_directory = os.path.dirname(current_directory)

# Tạo đường dẫn đầy đủ tới file CSV
csv_path = os.path.join(parent_directory, "Processed\\CartoonNetworkAsia_81Post_Processed.csv")

# Đọc file CSV
df = pd.read_csv(csv_path)

# %%
# thêm index cho dataframe
df = df.reset_index(inplace = False)
df["index"] = df["index"] + 1

# %%
df
# Out:
#     index          post_id                                          post_text  \
# 0       1  738496031649666  Celebrate #WB100 with sunset movies under the ...
# 1       2  738486251650644  Unlock your Barbie and Chelsea alter ego! Try ...
# 2       3  736838365148766  Looks like Tom won't be fishing in the Singapo...
# 3       4  737572781741991  The chase is on in the Singapore Botanic Garde...
# 4       5  736877231811546  Ready to rock some outdoor superhero moves? ⚡️...
# ..    ...              ...                                                ...
# 75     76  681911200641483  The claws are out this August with Cat-stravag...
# 76     77  681542050678398  Toontastic Kenergy all around 💯 Which of these...
# 77     78  681350087364261  Celebrate the 9 lives of Cats with Cat-stravag...
# 78     79  681290900703513  The iconic chase continues between Tom and Jer...
# 79     80  680769534088983  Did someone say FRIENDSHIP QUIZ? 👯‍♀️🧐 Happy I...
#
# ...

# %%
df[df['post_text'].str.contains('📺')]
# Out:
#     index          post_id                                          post_text  \
# 2       3  736838365148766  Looks like Tom won't be fishing in the Singapo...
# 3       4  737572781741991  The chase is on in the Singapore Botanic Garde...
# 7       8  735128465319756  Safe to say, we are definitely spooked! Don't ...
# 8       9  734200272079242  Do you have speed and wits like Jerry's? Try t...
# 9      10  728680649297871  Someone's got to tell Tom that what goes aroun...
# 12     13  731697605662842  Krampus' idea of hospitality includes a heap o...
# 14     15  731276915704911  Color up a storm with these #TomandJerrySingap...
# 15     16  728774962621773  Tom and Jerry have taken up a new hobby - kite...
# 16     17  729307375901865  Leave it up to Tom and Jerry to turn a relaxin...
# 19     20  728074599358476  The HEART is the off switch! 💔 Looks like a he...
# 20     21  727957666036836  Saving the day from the bad guys does have its...
# ...

# %%
# bài số 24 không phải chương trình

# %%
# số lượng các chương trình
taj = df[df['post_text'].str.contains('Tom and Jerry')]

# %%
taj
# Out:
#     index          post_id                                          post_text  \
# 2       3  736838365148766  Looks like Tom won't be fishing in the Singapo...
# 3       4  737572781741991  The chase is on in the Singapore Botanic Garde...
# 6       7  735935261905743  Make it a November to remember with Cartoon Ne...
# 8       9  734200272079242  Do you have speed and wits like Jerry's? Try t...
# 9      10  728680649297871  Someone's got to tell Tom that what goes aroun...
# 14     15  731276915704911  Color up a storm with these #TomandJerrySingap...
# 15     16  728774962621773  Tom and Jerry have taken up a new hobby - kite...
# 16     17  729307375901865  Leave it up to Tom and Jerry to turn a relaxin...
# 21     22  727323112766958  Grab a kite and head to Marina Barrage in Sing...
# 24     25  724556503043619  Pick up your pencils and sketch Jerry with us!...
# 27     28  720065946826008  It's Tom with a twist 🐱 Here's how Tom gets hi...
# ...

# %%
rgs = df[df['post_text'].str.contains('Regular Show')]

# %%
rgs
# Out:
#    index          post_id                                          post_text  \
# 7      8  735128465319756  Safe to say, we are definitely spooked! Don't ...
#
#    likes  comments  shares  reaction_count  like   love   wow  angry    haha  \
# 7   2614        31     218            5617  2614  554.0  20.0    4.0  2395.0
#
#    care  sad  hour        date      day
# 7  25.0  5.0    11  2023-10-31  Tuesday

# %%
ttg = df[df['post_text'].str.contains('Teen Titans Go')]

# %%
ttg
# Out:
#     index          post_id                                          post_text  \
# 12     13  731697605662842  Krampus' idea of hospitality includes a heap o...
# 50     51  696676182498318  Super-dog sitting sure looks like its giving R...
# 65     66  679095574256379  The perfect team bonding activity doesn’t exi-...
#
#     likes  comments  shares  reaction_count  like  love  wow  angry  haha  \
# 12    209         6      14             400   209  80.0  3.0    1.0  99.0
# 50    208         6      17             310   208  45.0  2.0    2.0  48.0
# 65    164         0      12             288   164  29.0  0.0    1.0  90.0
#
#     care  sad  hour        date        day
# 12   6.0  2.0    10  2023-10-25  Wednesday
# 50   5.0  0.0    19  2023-09-14   Thursday
# 65   4.0  0.0    19  2023-08-21     Monday

# %%
wbb = df[df['post_text'].str.contains('We Bare Bears')]

# %%
wbb
# Out:
#     index          post_id                                          post_text  \
# 19     20  728074599358476  The HEART is the off switch! 💔 Looks like a he...
# 46     47  709142917918311  Welcome to Panda's morning routine 😌 Full of o...
#
#     likes  comments  shares  reaction_count   like    love   wow  angry  \
# 19    330        14      32             600    330    95.0   5.0    4.0
# 46  12216        51     849           16373  12216  3747.0  12.0    3.0
#
#      haha   care  sad  hour        date       day
# 19  158.0    7.0  1.0    19  2023-10-19  Thursday
# 46   32.0  360.0  3.0    19  2023-09-18    Monday

# %%
b10 = df[df['post_text'].str.contains('Ben 10')]

# %%
b10
# Out:
#     index          post_id                                          post_text  \
# 20     21  727957666036836  Saving the day from the bad guys does have its...
#
#     likes  comments  shares  reaction_count  like  love  wow  angry  haha  \
# 20    176        11      17             264   176  68.0  0.0    1.0   4.0
#
#     care  sad  hour        date       day
# 20  15.0  0.0    10  2023-10-19  Thursday

# %%
adt = df[df['post_text'].str.contains('Adventure Time')]

# %%
adt
# Out:
#     index          post_id                                          post_text  \
# 25     26  723197599846176  The stakes have never been higher for Marcelin...
# 37     38  705393508293252  Only true fans know Finn was hiding that lusci...
#
#     likes  comments  shares  reaction_count   like    love   wow  angry  \
# 25   2454        19     157            3310   2454   757.0  12.0    2.0
# 37  10740       242    1200           24267  10740  7282.0  82.0    2.0
#
#       haha   care   sad  hour        date       day
# 25    59.0   25.0   1.0    11  2023-10-12  Thursday
# 37  5784.0  283.0  94.0    19  2023-09-28  Thursday

# %%
ltc = df[df['post_text'].str.contains('Looney Tunes Cartoons')]

# %%
ltc
# Out:
#     index          post_id                                          post_text  \
# 44     45  696664639166139  You gotta know when to stop! Unless of course....
# 67     68  687446800087923  Never a dull dinner with these two... 🐱🐥\n\n📺 ...
#
#     likes  comments  shares  reaction_count  like  love  wow  angry   haha  \
# 44    322         2      19             533   322  39.0  1.0    1.0  163.0
# 67    489         6      33             632   489  65.0  1.0    0.0   74.0
#
#     care  sad  hour        date        day
# 44   6.0  1.0    19  2023-09-20  Wednesday
# 67   3.0  0.0    19  2023-08-16  Wednesday

# %%
thqotvpi = df[df['post_text'].str.contains('The Heroic Quest Of The Valiant Prince Ivandoe')]

# %%
thqotvpi
# Out:
#     index          post_id                                          post_text  \
# 56     57  696662559166347  Is there anything Bertie can't do? 🐦 You can n...
#
#     likes  comments  shares  reaction_count  like  love  wow  angry  haha  \
# 56    159         7      12             244   159  34.0  1.0    0.0  49.0
#
#     care  sad  hour        date       day
# 56   1.0  0.0    19  2023-09-02  Saturday

# %%
cotc = df[df['post_text'].str.contains('Craig of the Creek')]

# %%
cotc
# Out:
#     index          post_id                                          post_text  \
# 62     63  694130402752896  It's a world of ooey-gooey wonder in the Slime...
# 75     76  681911200641483  The claws are out this August with Cat-stravag...
#
#     likes  comments  shares  reaction_count  like   love  wow  angry  haha  \
# 62    165         5      15             222   165   46.0  3.0    0.0   3.0
# 75    429        28      54             571   429  121.0  4.0    1.0   3.0
#
#     care  sad  hour        date        day
# 62   5.0  0.0    19  2023-08-23  Wednesday
# 75  13.0  0.0    10  2023-08-01    Tuesday

# %%
lp = df[df['post_text'].str.contains('Lamput')]

# %%
lp
# Out:
#     index          post_id                                          post_text  \
# 68     69  687982936700976  Elephant trunks not long enough? Lamput to the...
#
#     likes  comments  shares  reaction_count  like  love  wow  angry  haha  \
# 68    134         0       7             199   134  54.0  0.0    0.0   5.0
#
#     care  sad  hour        date       day
# 68   6.0  0.0    11  2023-08-12  Saturday

# %%
sycnfoha = df[df['post_text'].str.contains('Stream your Cartoon Network favorites on HBO Asia')]

# %%
sycnfoha
# Out:
#     index          post_id                                          post_text  \
# 39     40  713884147444188  This is NOT a drill - How many fluffy stacks o...
#
#     likes  comments  shares  reaction_count  like   love  wow  angry  haha  \
# 39    284         4      22             503   284  190.0  2.0    0.0  14.0
#
#     care  sad  hour        date      day
# 39  13.0  0.0    19  2023-09-26  Tuesday

# %%
bmdocn = df[df['post_text'].str.contains('Batman Day on Cartoon Network')]

# %%
bmdocn
# Out:
#     index          post_id                                          post_text  \
# 52     53  696675489165054  Watching the Batmobile rev into action, NEVER ...
# 55     56  696674449165158  Aquaman doesn't just pack a punch, he packs a ...
#
#     likes  comments  shares  reaction_count  like  love  wow  angry  haha  \
# 52    111         2      15             151   111  32.0  1.0    0.0   2.0
# 55    285         3      27             373   285  76.0  3.0    0.0   0.0
#
#     care  sad  hour        date        day
# 52   5.0  0.0    19  2023-09-11     Monday
# 55   9.0  0.0    19  2023-09-06  Wednesday

# %%
cyfcns = df[df['post_text'].str.contains('Catch your favorite Cartoon Network shows')]

# %%
cyfcns
# Out:
#     index          post_id                                          post_text  \
# 66     67  691907859641817  You're in for a reel treat on #WorldPhotograph...
#
#     likes  comments  shares  reaction_count  like  love  wow  angry  haha  \
# 66     76         3       7             117    76  36.0  1.0    0.0   1.0
#
#     care  sad  hour        date       day
# 66   3.0  0.0    11  2023-08-19  Saturday

# %%
csvz = df[df['post_text'].str.contains('Cat-stravaganza')]

# %%
csvz
# Out:
#     index          post_id                                          post_text  \
# 73     74  685208303645106  Celebrate the 9 lives of Cats with these 9 cat...
# 75     76  681911200641483  The claws are out this August with Cat-stravag...
# 77     78  681350087364261  Celebrate the 9 lives of Cats with Cat-stravag...
#
#     likes  comments  shares  reaction_count  like   love  wow  angry  haha  \
# 73    304        52      35             605   304  275.0  4.0    0.0   5.0
# 75    429        28      54             571   429  121.0  4.0    1.0   3.0
# 77    125         8       7             198   125   66.0  1.0    0.0   0.0
#
#     care  sad  hour        date      day
# 73  17.0  0.0    11  2023-08-07   Monday
# 75  13.0  0.0    10  2023-08-01  Tuesday
# 77   6.0  0.0    11  2023-07-31   Monday

# %%
# các chương trình được đăng bài
show_dict = {
    'tom and jerry': len(taj),
    'Regular Show': len(rgs),
    'Teen Titans Go': len(ttg),
    'We Bare Bears': len(wbb),
    'Ben 10': len(b10),
    'Adventure Time': len(adt),
    'Looney Tunes Cartoons': len(ltc),
    'The Heroic Quest Of The Valiant Prince Ivandoe': len(thqotvpi),
    'Craig of the Creek': len(cotc),
    'Lamput': len(lp),
    'Stream your Cartoon Network favorites on HBO Asia': len(sycnfoha),
    'Batman Day on Cartoon Network': len(bmdocn),
    'Catch your favorite Cartoon Network shows': len(cyfcns),
    'Cat-stravaganza': len(csvz)
}

# %%
# tỉ trọng số bài đăng giữa các chương trình
show = []
post = []

explode = (0.1, 0.0, 0.2, 0.3, 0.0, 0.2, 0.4, 0.3, 0.2, 0.5, 0.2, 0.0, 0.1, 0.0)

for x, y in show_dict.items():
    show.append(x)
    post.append(y)

plt.pie(post, labels=['']*len(show), autopct='%.2f', explode = explode, startangle = 90)

plt.axis('equal')
plt.title("Tỉ trọng số lượng bài đăng về các chương trình")

plt.legend(show, title="Shows", loc="center left", bbox_to_anchor=(1, 0.5))

plt.show()

# %%
show_dict
# Out:
# {'tom and jerry': 23,
#  'Regular Show': 1,
#  'Teen Titans Go': 3,
#  'We Bare Bears': 2,
#  'Ben 10': 1,
#  'Adventure Time': 2,
#  'Looney Tunes Cartoons': 2,
#  'The Heroic Quest Of The Valiant Prince Ivandoe': 1,
#  'Craig of the Creek': 2,
#  'Lamput': 1,
#  'Stream your Cartoon Network favorites on HBO Asia': 1,
#  'Batman Day on Cartoon Network': 2,
#  'Catch your favorite Cartoon Network shows': 1,
#  'Cat-stravaganza': 3}

# %%
# số bài đăng của từng chương trình
plt.barh(show, post)

for i, v in enumerate(post):
    plt.text(v + 0.5, i, str(v), color='black', va='center')

plt.xlim(0, max(post) + 2)
plt.show()

# %%
# reaction các bài đăng của từng chương trình
reaction_dict = {
    'tom and jerry': sum(taj.reaction_count),
    'Regular Show': sum(rgs.reaction_count),
    'Teen Titans Go': sum(ttg.reaction_count),
    'We Bare Bears': sum(wbb.reaction_count),
    'Ben 10': sum(b10.reaction_count),
    'Adventure Time': sum(adt.reaction_count),
    'Looney Tunes Cartoons': sum(ltc.reaction_count),
    'The Heroic Quest Of The Valiant Prince Ivandoe': sum(thqotvpi.reaction_count),
    'Craig of the Creek': sum(cotc.reaction_count),
    'Lamput': sum(lp.reaction_count),
    'Stream your Cartoon Network favorites on HBO Asia': sum(sycnfoha.reaction_count),
    'Batman Day on Cartoon Network': sum(bmdocn.reaction_count),
    'Catch your favorite Cartoon Network shows': sum(cyfcns.reaction_count),
    'Cat-stravaganza': sum(csvz.reaction_count)
}

# %%
# reaction các bài đăng của từng chương trình
reaction_dict_2 = {
    'tom and jerry': sum(taj.reaction_count),
    'Regular Show': sum(rgs.reaction_count),
    'We Bare Bears': sum(wbb.reaction_count),
    'Adventure Time': sum(adt.reaction_count),
    'Others': sum(ttg.reaction_count) + sum(b10.reaction_count) + sum(ltc.reaction_count)
                + sum(thqotvpi.reaction_count) + sum(cotc.reaction_count) + sum(lp.reaction_count) + sum(sycnfoha.reaction_count)
                + sum(cyfcns.reaction_count) + sum(csvz.reaction_count) + sum(bmdocn.reaction_count)
}

# %%
# tỉ trọng số lượng reaction giữa các chương trình
show = []
reaction = []

explode = (0.1, 0.0, 0.2, 0.2, 0.0)

for x, y in reaction_dict_2.items():
    show.append(x)
    reaction.append(y)

plt.pie(reaction, labels=['']*len(show), autopct='%.2f', explode = explode, startangle = 90)

plt.axis('equal')
plt.title("Tỉ trọng số lượng reaction giữa các chương trình")

plt.legend(show, title="Shows", loc="center left", bbox_to_anchor=(1, 0.5))

# %%
# số lượng reaction của từng chương trình
show = []
reaction = []

for x, y in reaction_dict.items():
    show.append(x)
    reaction.append(y)

plt.barh(show, reaction)

for i, v in enumerate(reaction):
    plt.text(v + 0.5, i, str(v), color='black', va='center')

plt.xlim(0, 1.125 * max(reaction))
plt.show()

# %%
# số lượng reaction của các bài đăng về Tom and Jerry
taj_plt = taj.plot(kind = "bar", x = "index", y = "reaction_count", figsize = (15, 5), xlabel = "tom and jerry index", ylabel = "reaction")

for bar in taj_plt.patches:
    taj_plt.annotate(str(bar.get_height()), (bar.get_x() + bar.get_width() / 2, bar.get_height()), ha = 'center', va = 'center', xytext = (0, 5), textcoords = 'offset points')

# %%
# số lượng reaction của các bài đăng về Adventure Time
adt_plt = adt.plot(kind = "bar", x = "index", y = "reaction_count", xlabel = "adventure time index", ylabel = "reaction")

for bar in adt_plt.patches:
    adt_plt.annotate(str(bar.get_height()), (bar.get_x() + bar.get_width() / 2, bar.get_height()), ha = 'center', va = 'center', xytext = (0, 5), textcoords = 'offset points')

# %%
# số lượng reaction của các bài đăng về We Bare Bear
wbb_plt = wbb.plot(kind = "bar", x = "index", y = "reaction_count", xlabel = "we bare bear index", ylabel = "reaction")

for bar in wbb_plt.patches:
    wbb_plt.annotate(str(bar.get_height()), (bar.get_x() + bar.get_width() / 2, bar.get_height()), ha = 'center', va = 'center', xytext = (0, 5), textcoords = 'offset points')

# %%
# các bài đăng nổi bật
df_top = df.iloc[[37, 45, 46, 51, 59, 72, 78]]

# %%
df_top
# Out:
#     index          post_id                                          post_text  \
# 37     38  705393508293252  Only true fans know Finn was hiding that lusci...
# 45     46  709815014517768  All the adventure you never knew you needed! C...
# 46     47  709142917918311  Welcome to Panda's morning routine 😌 Full of o...
# 51     52  706162411549695  Tom the blob monster vs Village mice: 1-0 🟢\n\...
# 59     60  697917729040830  Sorry Tom, The New York animals sure are #Team...
# 72     73  681821073983829  Durians - do we love them? Tom and Jerry sure ...
# 78     79  681290900703513  The iconic chase continues between Tom and Jer...
#
#     likes  comments  shares  reaction_count   like    love   wow  angry  \
# 37  10740       242    1200           24267  10740  7282.0  82.0    2.0
# 45   5992        27     330            6694   5992   401.0   6.0    0.0
# 46  12216        51     849           16373  12216  3747.0  12.0    3.0
# ...

# %%
# lượng reaction của các bài đăng trên
df_top_plt = df_top.plot(kind = 'bar', x = 'index', y = 'reaction_count', xlabel = 'post', ylabel = 'reaction')
for bar in df_top_plt.patches:
    df_top_plt.annotate(str(bar.get_height()), (bar.get_x() + bar.get_width() / 2, bar.get_height()), ha = 'center', va = 'center', xytext = (0, 5), textcoords = 'offset points')

# %%
df[~df['post_text'].str.contains('📺')]
# Out:
#     index          post_id                                          post_text  \
# 0       1  738496031649666  Celebrate #WB100 with sunset movies under the ...
# 1       2  738486251650644  Unlock your Barbie and Chelsea alter ego! Try ...
# 4       5  736877231811546  Ready to rock some outdoor superhero moves? ⚡️...
# 5       6  736841875148415  Only 1 WEEK until a century of Warner Brothers...
# 6       7  735935261905743  Make it a November to remember with Cartoon Ne...
# 10     11  732905262208743  ONE HUNDRED years of amazing storytelling and ...
# 11     12  732863468879589  To make your future dreams come true, it's bes...
# 13     14  731674645665138  Typhoon Trouble! 🌀😲 Be blown away as The Power...
# 17     18  728772562622013  Can you imagine a world without electricity 💡 ...
# 18     19  728600115972591  Step into a world of pure imagination. ✨\n#Won...
# 22     23  726619596170643  Take to the skies at the Kite Flying Fiesta wi...
# ...

# %%
out_show_plt = df[~df['post_text'].str.contains('📺')].plot(kind = "bar", x = "index", y = "reaction_count", figsize = (15,7))
for bar in out_show_plt.patches:
    out_show_plt.annotate(str(bar.get_height()), (bar.get_x() + bar.get_width() / 2, bar.get_height()), ha = 'center', va = 'center', xytext = (0, 5), textcoords = 'offset points')

# %%
print(len(df[~df['post_text'].str.contains('📺')]))
print(len(df[df['post_text'].str.contains('📺')]))
# Out:
# 34
# 46

# %%
pd.Series(reaction_dict).median()
# Out:
# 895.5

# %%
df[~df['post_text'].str.contains('📺')].reaction_count.median()
# Out:
# 101.5
