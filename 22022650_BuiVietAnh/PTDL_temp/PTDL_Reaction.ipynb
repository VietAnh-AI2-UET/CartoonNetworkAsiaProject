# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Lấy đường dẫn của thư mục hiện tại
current_directory = os.getcwd()

# Lấy đường dẫn của thư mục cha
parent_directory = os.path.dirname(current_directory)

# Tạo đường dẫn đầy đủ tới file CSV
csv_path = os.path.join(parent_directory, "Processed\\CartoonNetworkAsia_81Post_Processed.csv")

# Đọc file CSV
df = pd.read_csv(csv_path)

# %%
# thêm index cho dataframe
df = df.reset_index(inplace = False)
df["index"] = df["index"] + 1

# %%
df
# Out:
#     index          post_id                                          post_text  \
# 0       1  738496031649666  Celebrate #WB100 with sunset movies under the ...
# 1       2  738486251650644  Unlock your Barbie and Chelsea alter ego! Try ...
# 2       3  736838365148766  Looks like Tom won't be fishing in the Singapo...
# 3       4  737572781741991  The chase is on in the Singapore Botanic Garde...
# 4       5  736877231811546  Ready to rock some outdoor superhero moves? ⚡️...
# ..    ...              ...                                                ...
# 75     76  681911200641483  The claws are out this August with Cat-stravag...
# 76     77  681542050678398  Toontastic Kenergy all around 💯 Which of these...
# 77     78  681350087364261  Celebrate the 9 lives of Cats with Cat-stravag...
# 78     79  681290900703513  The iconic chase continues between Tom and Jer...
# 79     80  680769534088983  Did someone say FRIENDSHIP QUIZ? 👯‍♀️🧐 Happy I...
#
# ...

# %%
# 10 bài có lượng reaction cao nhất
df.sort_values(by = ['reaction_count'], ascending = False).head(10)
# Out:
#     index          post_id                                          post_text  \
# 59     60  697917729040830  Sorry Tom, The New York animals sure are #Team...
# 37     38  705393508293252  Only true fans know Finn was hiding that lusci...
# 46     47  709142917918311  Welcome to Panda's morning routine 😌 Full of o...
# 51     52  706162411549695  Tom the blob monster vs Village mice: 1-0 🟢\n\...
# 72     73  681821073983829  Durians - do we love them? Tom and Jerry sure ...
# 45     46  709815014517768  All the adventure you never knew you needed! C...
# 78     79  681290900703513  The iconic chase continues between Tom and Jer...
# 7       8  735128465319756  Safe to say, we are definitely spooked! Don't ...
# 31     32  717243337108269  The familiar opening theme song of our favorit...
# 25     26  723197599846176  The stakes have never been higher for Marcelin...
#
#     likes  comments  shares  reaction_count   like    love   wow  angry  \
# ...

# %%
# biểu diễn bằng biểu đồ
top_react = df.sort_values(by = ['reaction_count'], ascending = False).head(10)
top_react_plt = top_react.plot(kind = "bar", x = 'index', y = 'reaction_count')

for bar in top_react_plt.patches:
    top_react_plt.annotate(str(bar.get_height()), (bar.get_x() + bar.get_width() / 2, bar.get_height()), ha = 'center', va = 'center', xytext = (0, 5), textcoords = 'offset points')

plt.show()

# %%
# giờ đăng bài
top_hour = df.sort_values(by = ['reaction_count'], ascending = False).head(10).plot(kind = 'bar', x = 'index', y = 'hour')

for bar in top_hour.patches:
    top_hour.annotate(str(bar.get_height()), (bar.get_x() + bar.get_width() / 2., bar.get_height()), ha='center', va='center', xytext=(0, 5), textcoords='offset points')

plt.show()

# %%
# Quan hệ giữa giờ đăng bài và reaction
react_hour = df[["reaction_count", "hour"]].groupby(["hour"]).sum("reaction_count")
react_hour_plt = react_hour.plot(kind = "bar")
for b in react_hour_plt.patches:
    react_hour_plt.annotate(str(b.get_height()), (b.get_x() + b.get_width() / 2., b.get_height()), ha='center', va='center', xytext=(0, 5), textcoords='offset points')

plt.show()

# %%
# Nội dung của top các bài đăng
df.sort_values(by = ['reaction_count'], ascending = False).head(10)[["index", "post_text"]]
# Out:
#     index                                          post_text
# 59     60  Sorry Tom, The New York animals sure are #Team...
# 37     38  Only true fans know Finn was hiding that lusci...
# 46     47  Welcome to Panda's morning routine 😌 Full of o...
# 51     52  Tom the blob monster vs Village mice: 1-0 🟢\n\...
# 72     73  Durians - do we love them? Tom and Jerry sure ...
# 45     46  All the adventure you never knew you needed! C...
# 78     79  The iconic chase continues between Tom and Jer...
# 7       8  Safe to say, we are definitely spooked! Don't ...
# 31     32  The familiar opening theme song of our favorit...
# 25     26  The stakes have never been higher for Marcelin...

# %%
# ngày đăng bài
df.sort_values(by = ['reaction_count'], ascending = False).head(10)[['index', 'date']]
# Out:
#     index        date
# 59     60  2023-08-30
# 37     38  2023-09-28
# 46     47  2023-09-18
# 51     52  2023-09-13
# 72     73  2023-08-07
# 45     46  2023-09-19
# 78     79  2023-07-31
# 7       8  2023-10-31
# 31     32  2023-10-02
# 25     26  2023-10-12

# %%
# quan hệ của số lượng reaction và ngày đăng bài
top_react = df.sort_values(by = ['reaction_count'], ascending = False).head(10)
top_react_date = top_react.sort_values(by = ['date'], ascending = True)
top_react_date_plt = top_react_date.plot(kind = 'bar', x = 'date', y = 'reaction_count')
i = 0

for bar in top_react_date_plt.patches:
    top_react_date_plt.annotate("(" + str(top_react_date.iloc[i]["index"]) + ")\n" + str(bar.get_height()), (bar.get_x() + bar.get_width() / 2., bar.get_height()), ha='center', va='center', xytext=(0, 12), textcoords='offset points')
    i += 1

extra_space = 0.15 
plt.ylim(top=top_react_date["reaction_count"].max() * (1 + extra_space))

plt.show()
